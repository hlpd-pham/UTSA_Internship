# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')

# %%
df = pd.read_excel('data.xlsx')
df.head()
# Out:
#    OPEID                                               Name  \
# 0   1002  ALABAMA AGRICULTURAL & MECHANICAL UNIVERSITY  ...
# 1   1003  FAULKNER UNIVERSITY                           ...
# 2   1004  UNIVERSITY OF MONTEVALLO                      ...
# 3   1005  ALABAMA STATE UNIVERSITY                      ...
# 4   1007  CENTRAL ALABAMA COMMUNITY COLLEGE             ...
#
#                                              Address                  City  \
# 0  4900 MERIDIAN STREET                          ...  NORMAL
# 1  5345 ATLANTA HIGHWAY                          ...  MONTGOMERY
# 2  PALMER CIRCLE                                 ...  MONTEVALLO
# 3  915 SOUTH JACKSON STREET                      ...  MONTGOMERY
# 4  1675 CHEROKEE ROAD                            ...  ALEXANDER CITY
#
#   State                                         State Desc Zip Code Zip Ext  \
# 0    AL  ALABAMA                                       ...    35762    1357
# ...

# %%
df = df.sort_values('State')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4712 entries, 3574 to 2287
# Data columns (total 29 columns):
# OPEID           4712 non-null int64
# Name            4712 non-null object
# Address         4712 non-null object
# City            4712 non-null object
# State           4712 non-null object
# State Desc      4712 non-null object
# Zip Code        4712 non-null object
# Zip Ext         4712 non-null object
# Prog
# Length     4712 non-null int64
# School
# Type     4712 non-null int64
# Year 1          4712 non-null int64
# Dual
# Num 1      4712 non-null int64
# Dual
# Denom 1    4712 non-null int64
# DRate 1         4712 non-null float64
# PRate 1         4712 non-null object
# Ethnic Code     4712 non-null int64
# Program         4712 non-null object
# Cong Dis        4712 non-null object
# Region          4712 non-null int64
# Year 2          4712 non-null int64
# Dual
# Num 2      4712 non-null int64
# Dual
# Denom 2    4712 non-null int64
# ...

# %%
df = df.reset_index().drop('index',axis=1)

# %%
df.head()
# Out:
#    OPEID                                               Name  \
# 0  25410  ALASKA CAREER COLLEGE                         ...
# 1   1061  ALASKA PACIFIC UNIVERSITY                     ...
# 2   1063  UNIVERSITY OF ALASKA FAIRBANKS                ...
# 3   1065  UNIVERSITY OF ALASKA SOUTHEAST                ...
# 4  31603  AVTEC - ALASKA'S INSTITUTE OF TECHNOLOGY      ...
#
#                                              Address                  City  \
# 0  1415 E. TUDOR ROAD                            ...  ANCHORAGE
# 1  4101 UNIVERSITY DRIVE                         ...  ANCHORAGE
# 2  3RD FLOOR, SIGNER'S HALL                      ...  FAIRBANKS
# 3  11066 AUKE LAKE WAY                           ...  JUNEAU
# 4  809 SECOND AVENUE                             ...  SEWARD
#
#   State                                         State Desc Zip Code Zip Ext  \
# 0    AK  ALASKA                                        ...    99507    1033
# ...

# %%
Texas = df[df['State']=='TX'].copy()

# %%
Texas.head()
# Out:
#       OPEID                                               Name  \
# 4063  41255  MANUEL AND THERESA'S SCHOOL OF HAIR DESIGN    ...
# 4064   3539  ALVIN COMMUNITY COLLEGE                       ...
# 4065  41254  PAUL MITCHELL THE SCHOOL AUSTIN               ...
# 4066  40823  PROFESSIONAL CAREER TRAINING INSTITUTE        ...
# 4067  40894  CCI TRAINING CENTER                           ...
#
#                                                 Address                  City  \
# 4063  220 NORTH MAIN STREET                         ...  BRYAN
# 4064  3110 MUSTANG ROAD                             ...  ALVIN
# 4065  9503 RESEARCH BOULEVARD            BUILDING 3,...  AUSTIN
# 4066  227 WEST AIRTEX BOULEVARD                     ...  HOUSTON
# 4067  770 E. ROAD TO SIX FLAGS # 140                ...  ARLINGTON
#
#      State                                         State Desc Zip Code  \
# 4063    TX  TEXAS                                         ...    77803
# ...

# %%
Texas_public = Texas[Texas['School\nType']==1]

# %%
Texas_public
# Out:
#       OPEID                                               Name  \
# 4064   3539  ALVIN COMMUNITY COLLEGE                       ...
# 4072   3541  ANGELO STATE UNIVERSITY                       ...
# 4075   3540  AMARILLO COLLEGE                              ...
# 4076   3630  PRAIRIE VIEW AGRICULTURAL & MECHANICAL UNIVERS...
# 4078   4003  CENTRAL TEXAS COLLEGE DISTRICT                ...
# 4079  42485  TEXAS A&M UNIVERSITY-SAN ANTONIO              ...
# 4080  42439  UNIVERSITY OF TEXAS HEALTH SCIENCE CENTER AT T...
# 4081  42421  UNIVERSITY OF NORTH TEXAS AT DALLAS           ...
# 4082  42295  TEXAS A&M UNIVERSITY - CENTRAL TEXAS          ...
# 4087   3546  COASTAL BEND COLLEGE                          ...
# 4096   3558  NORTH CENTRAL TEXAS COLLEGE                   ...
# 4097   3553  CISCO COLLEGE                                 ...
# 4099   3612  UNIVERSITY OF HOUSTON - DOWNTOWN              ...
# 4100   3611  SOUTH PLAINS COLLEGE                          ...
# ...

# %%
sns.distplot(Texas['DRate 1'], hist_kws={'edgecolor':'k'})
# Out:
# C:\Users\rzz934\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(Texas['DRate 2'], hist_kws={'edgecolor':'k'})
# Out:
# C:\Users\rzz934\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(Texas['DRate 3'], hist_kws={'edgecolor':'k'})
# Out:
# C:\Users\rzz934\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
utsa = Texas[Texas['Name'].str.contains('UNIVERSITY OF TEXAS AT SAN ANTONIO')]

# %%
utsa[['DRate 1','DRate 2','DRate 3']]
# Out:
#       DRate 1  DRate 2  DRate 3
# 4249      5.8      7.2      8.6

# %%
Texas['DRate 1'].mean()
# Out:
# 13.391570881226059

# %%
Texas['DRate 2'].mean()
# Out:
# 13.124137931034472

# %%
Texas['DRate 3'].mean()
# Out:
# 13.391570881226059
